# %% [markdown]
#  # Lorenz Attractor

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def lorenz(x, y, z, s=10, r=28, b=2.667):
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot

# %%
dt = 0.01
num_steps = 10000

xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)

xs[0], ys[0], zs[0] = (0., 1., 1.05)

# %%
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

ax = plt.figure(figsize=(10,8)).add_subplot(projection='3d')

ax.plot(xs, ys, zs, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor 3D")

plt.show()

# %%
x = -10
y = -6
z = 20.0

xt = []
yt = []

dt = 0.001
sigma = 10.0
R = 28.0
b = 8.0/3.0
theta = 3.0 * math.pi / 4.0  

for t in np.arange(0,10,dt):
  dxdt = sigma * (-x + y)
  dydt = R*x - x*z - y
  dzdt = -b*z + x*y
  x = x + dxdt*dt
  y = y + dydt*dt
  z = z + dzdt*dt
  x_p = np.cos(theta) * x - np.sin(theta) * y
  y_p = np.sin(theta) * x + np.cos(theta) * y
  xt.append(x_p)
  yt.append(z)
 
plt.xlabel('x') 
plt.ylabel('z') 

plt.title('Lorenz Attractor 2D')

plt.plot(xt,yt)

plt.axis('equal')
# Out:
# (-28.484849917850344, 29.037552147741092, 7.271991115470726, 44.37841940124599)
